# %%
import json
import glob



def filter_chars(char):
    ignored_chars = ["/", "\\", "_"]
    if char not in ingored_chars:
        return True
    else:
        return False


knowledge = []
page_number =5
# reading all json files
jsons = glob.glob("../images/*/*.json")
print(jsons)
for file in jsons:
    if file == f"../images/page_number_{page_number}/results.json":
        print(file)
        with open(file) as user_file:
            knowledge.extend(json.loads(user_file.read()))
# Out:
# ['../images/page_number_4/results.json', '../images/page_number_2/results.json', '../images/page_number_3/results.json', '../images/page_number_0/results.json', '../images/page_number_5/results.json', '../images/page_number_1/results.json']
# ../images/page_number_5/results.json

# %%
knowledge
# Out:
# [{'id': '130381a3-8fc5-4221-8a74-266dcfb4f286',
#   'display': 'test/5.png',
#   'bbox': ['529', '402', '4042', '598'],
#   'text': 'Body Controller Right B,W,J,D XO50A B X051 X052 X054 X060A B X062 X053A B X055 X056 X058 X059',
#   'text_to_ignore': []},
#  {'id': 'f1260115-5cd6-48b2-8a55-5ab54b4db1fa',
#   'display': 'test/5.png',
#   'bbox': ['1098', '704', '1840', '832'],
#   'text': 'X050B-10 High-Side Drive RADIO TUNER',
#   'text_to_ignore': []},
#  {'id': '695fc50c-3e46-4d08-bc33-b212d2a9fb09',
#   'display': 'test/5.png',
#   'bbox': ['20', '886', '132', '926'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '6683336b-2f6e-4b13-a455-f0996fe2256c',
#   'display': 'test/5.png',
#   'bbox': ['534', '1164', '3887', '1346'],
#   'text': 'MCU & Gateway W,B,J,A X452 X453 X454 X800 X803 X801 X804 X802 X829 X860 X862 X455',
#   'text_to_ignore': []},
#  {'id': 'a6ddd307-5600-4b08-a1e1-422f18444532',
#   'display': 'test/5.png',
#   'bbox': ['1950', '802', '2164', '858'],
#   'text': '——X050B',
#   'text_to_ignore': []},
#  {'id': '77b6866f-8349-4e39-94a6-ec0f96f9f97e',
#   'display': 'test/5.png',
#   'bbox': ['3756', '687', '3995', '750'],
#   'text': 'X922M',
#   'text_to_ignore': []},
#  {'id': '8caa944c-0eef-4cac-b0a4-961a09bd6d8e',
#   'display': 'test/5.png',
#   'bbox': ['2602', '704', '3390', '826'],
#   'text': 'PAC11-B RD 0.35 FLRY ~CPGB 2594.0 3486395-XxX (B)',
#   'text_to_ignore': []},
#  {'id': '450b0b7f-1971-4f6d-8f1f-98eb4bcbc47f',
#   'display': 'test/5.png',
#   'bbox': ['4050', '688', '4278', '750'],
#   'text': '—- X922F',
#   'text_to_ignore': []},
#  {'id': '4accda82-6cfb-4302-a90b-0e8666fdf6e6',
#   'display': 'test/5.png',
#   'bbox': ['4738', '702', '5524', '830'],
#   'text': 'PAC11-A RD 0.35 FLRY ~CPGB 2321.0 3486406-XxX (T)',
#   'text_to_ignore': []},
#  {'id': '59517383-354e-41e1-b7bf-7b55591c534f',
#   'display': 'test/5.png',
#   'bbox': ['6226', '336', '7520', '596'],
#   'text': '~CPGB Radio Tuner T,LT X439 X805F X807F',
#   'text_to_ignore': []},
#  {'id': '986baf2a-2c31-48e0-843d-faa890947d3b',
#   'display': 'test/5.png',
#   'bbox': ['6286', '702', '6788', '832'],
#   'text': 'X439-1 Power In ACC',
#   'text_to_ignore': []},
#  {'id': '06cf7919-48f0-4d8b-816e-a622018051e7',
#   'display': 'test/5.png',
#   'bbox': ['6982', '852', '7456', '980'],
#   'text': 'X439-4 Ground Ground',
#   'text_to_ignore': []},
#  {'id': '1f4617e8-5446-4724-839b-600a08f89a5d',
#   'display': 'test/5.png',
#   'bbox': ['7574', '950', '7768', '1008'],
#   'text': '439',
#   'text_to_ignore': []},
#  {'id': '976fd712-f2cf-4bdf-b69e-f3d529bf7a89',
#   'display': 'test/5.png',
#   'bbox': ['7958', '854', '8722', '978'],
#   'text': 'GDLO1-H BK 0.35 FLRY ~CPGB 317.0 3486406-XxX (T)',
#   'text_to_ignore': []},
#  {'id': 'dd1d1da1-83cb-4903-896c-e8a57742a709',
#   'display': 'test/5.png',
#   'bbox': ['9032', '852', '10014', '1018'],
#   'text': '> GDLO1-A BK 1.00 FLRY 612.0 3486406-XX (T) Z52-GDLO1',
#   'text_to_ignore': []},
#  {'id': '8b3b7210-f596-422e-b8e4-074cabbab42f',
#   'display': 'test/5.png',
#   'bbox': ['1164', '1452', '1836', '1582'],
#   'text': 'X454-11 Ethernet2Wire RADIO-BR-ETH P',
#   'text_to_ignore': []},
#  {'id': 'a6d19e73-59ec-410b-8b04-44b84e090385',
#   'display': 'test/5.png',
#   'bbox': ['1164', '1602', '1834', '1732'],
#   'text': 'X454-12 Ethernet2Wire RADIO-BR-ETH N',
#   'text_to_ignore': []},
#  {'id': 'de52a9a7-78c6-44b9-9801-fc2fdb06d052',
#   'display': 'test/5.png',
#   'bbox': ['1950', '1437', '3994', '1758'],
#   'text': 'CAU50-A BU 0.35 FLRY TWIST-A2B CAUSO-A ~CPGB 2376.0 3486395- XB) WIST-A2B CAU50-A CAU51-A WH 0.35 FLRY. X922M x922M X454 ~CPGB 2376.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '81e412c0-4eea-4fd4-90b8-e15b5bb8e292',
#   'display': 'test/5.png',
#   'bbox': ['1256', '2273', '1837', '2410'],
#   'text': 'X453-9 Analog Out AMP1 2 P (DOOR FL)',
#   'text_to_ignore': []},
#  {'id': 'd7954304-0214-450b-a6b5-f42407180076',
#   'display': 'test/5.png',
#   'bbox': ['2075', '2262', '5042', '2580'],
#   'text': '- X986M AUDO7 A-A WH 0.50 FLRY X986F AUDO7 A-A WH 0.50 FLRY . 871.0 3486395-Xx (B J i“ 14 1412.0 3486394-Xx (A) J — TWIST. -AUDO? A-A TWIST. AUDO7 A-A . TWIST aUD07 A -C TWIST AUDO7 A-C UD08 A-A BU 0.50 FLRY [ over 13113 —X986M UD08 AA BU 0.50 FLRY 871.0 3486395-XX (B) f f 1412.0 3486394-XXxX (A ) X032',
#   'text_to_ignore': []},
#  {'id': '4dd776b6-5959-4aad-81f2-22e2f5d1986f',
#   'display': 'test/5.png',
#   'bbox': ['1236', '2422', '1836', '2560'],
#   'text': 'X453-10 Analog Out AMP1 2 N (DOOR FL)',
#   'text_to_ignore': []},
#  {'id': '4cbe0bc3-0f71-433d-a8ef-f94879d8ffcc',
#   'display': 'test/5.png',
#   'bbox': ['4016', '1440', '6170', '1760'],
#   'text': ') X922F CAU50-B BU 0.35. FLRY 2 ~CPGB 2321.0 3486406-XX (1) rN y900F TWIST-BRR CAU50-B TWIST-BRR CAU50-B X922F CAUS1-B WH 0.35 FLRY 3 ~ ~CPGB 2321.0 3486406-XX (1) Ih J X439',
#   'text_to_ignore': []},
#  {'id': '2b833513-63a0-401e-97c4-ef8f939e87fd',
#   'display': 'test/5.png',
#   'bbox': ['6286', '1453', '6796', '1578'],
#   'text': 'X439-7 Digital In BR+',
#   'text_to_ignore': []},
#  {'id': '31791232-cb6d-417a-86a5-ebb944caf5ed',
#   'display': 'test/5.png',
#   'bbox': ['6288', '1606', '6794', '1728'],
#   'text': 'X439-9 Digital In BR-',
#   'text_to_ignore': []},
#  {'id': '3d359237-f539-4412-868f-8597db5cfa69',
#   'display': 'test/5.png',
#   'bbox': ['5103', '2053', '8396', '2248'],
#   'text': 'Body Controller Left AW,J,D X030A B X031 X032 X034 X038A B X039 X037 X033A B X035 X036',
#   'text_to_ignore': []},
#  {'id': 'e960ad08-1157-4e3b-825c-d1fa3d684178',
#   'display': 'test/5.png',
#   'bbox': ['5161', '2279', '7236', '2406'],
#   'text': 'X032-4 Pass-through X033B-10 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH P AUDIO FRONT DOOR 2 PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': '1cd0d754-b0d6-4fd1-bb9f-bb8e7f19578a',
#   'display': 'test/5.png',
#   'bbox': ['5162', '2429', '7236', '2564'],
#   'text': 'X032-3 Pass-through X033B-19 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH N AUDIO FRONT DOOR 2 PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': '18528ff0-21ee-4699-ad6a-632bcde106f3',
#   'display': 'test/5.png',
#   'bbox': ['7476', '2378', '8030', '2448'],
#   'text': 'TWIST AUDO7 B-B',
#   'text_to_ignore': []},
#  {'id': '4fbe0e17-6a9d-47a1-9726-eae8b9ff82c4',
#   'display': 'test/5.png',
#   'bbox': ['7354', '2530', '7562', '2582'],
#   'text': 'X033B',
#   'text_to_ignore': []},
#  {'id': 'ac2f9ed1-4542-4963-b25e-e1f53caace09',
#   'display': 'test/5.png',
#   'bbox': ['8162', '2280', '9492', '2550'],
#   'text': 'AUDO7 B-A WH 0.50 FLRY LHST 1383.13941 2486397-XX (D) TWIST AUDO7 B-B AUDO8 B-A YE 0.50 FLRY LHST 1383.13941 2486397-XX (D)',
#   'text_to_ignore': []},
#  {'id': 'cf4fb6a7-877f-4f25-a6fd-16b1a686fee1',
#   'display': 'test/5.png',
#   'bbox': ['9532', '2264', '9770', '2324'],
#   'text': 'X927M(',
#   'text_to_ignore': []},
#  {'id': '6fb0bc31-b1c1-4fb2-9cea-9e57bc8d6639',
#   'display': 'test/5.png',
#   'bbox': ['9824', '2264', '10052', '2326'],
#   'text': 'X927F',
#   'text_to_ignore': []},
#  {'id': 'de77ad4e-3854-4665-855d-909864295c93',
#   'display': 'test/5.png',
#   'bbox': ['9792', '2413', '10052', '2526'],
#   'text': ') - X927F',
#   'text_to_ignore': []},
#  {'id': '266b3166-8a82-478e-a406-2e56a0f6bbc7',
#   'display': 'test/5.png',
#   'bbox': ['9532', '2414', '9768', '2476'],
#   'text': 'X927M',
#   'text_to_ignore': []},
#  {'id': '34e0ef3e-5f29-49f8-86e4-7b4392f7b3b0',
#   'display': 'test/5.png',
#   'bbox': ['9790', '2536', '9904', '2568'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '805aee39-4b9e-4847-b8e2-bf7159fb09fd',
#   'display': 'test/5.png',
#   'bbox': ['10224', '1742', '10340', '1774'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': 'de66cc32-98b5-4366-a083-523f182fd4d0',
#   'display': 'test/5.png',
#   'bbox': ['10218', '1804', '10368', '1962'],
#   'text': 'vLOD',
#   'text_to_ignore': []},
#  {'id': '565f3149-819f-4b8d-aa22-9fe486063c4d',
#   'display': 'test/5.png',
#   'bbox': ['10190', '2278', '11426', '2550'],
#   'text': 'AUDO7 B-A WH 0.75 FLRY LHST 865.0 1613836-XX (DT) TWIST AUDO7 B-D AUDO8 B-A YE 0.75 FLRY LHST 865.0 1613836-XX (DT)',
#   'text_to_ignore': []},
#  {'id': '475260ad-4b0b-4e81-b9c2-5c99f4598b22',
#   'display': 'test/5.png',
#   'bbox': ['12377', '2064', '13484', '2240'],
#   'text': 'Speaker Door Front Fullrange DT X424',
#   'text_to_ignore': []},
#  {'id': '7ab96623-e27f-4167-afff-0e7505ce5268',
#   'display': 'test/5.png',
#   'bbox': ['12435', '2280', '12936', '2412'],
#   'text': 'X424-1 Power In Speaker P',
#   'text_to_ignore': []},
#  {'id': 'ccd6c3af-1a6a-4326-b5de-a0d9e4a945da',
#   'display': 'test/5.png',
#   'bbox': ['11629', '2377', '12192', '2450'],
#   'text': 'TWIST AUDO7 B-D',
#   'text_to_ignore': []},
#  {'id': 'fda50a44-8505-4fb7-b48a-ce75facc6d3e',
#   'display': 'test/5.png',
#   'bbox': ['12435', '2430', '12936', '2562'],
#   'text': 'X424-2 Power In Speaker N',
#   'text_to_ignore': []},
#  {'id': 'da1d0239-f204-45f8-87b0-157e26481285',
#   'display': 'test/5.png',
#   'bbox': ['12132', '2528', '12314', '2574'],
#   'text': 'X424',
#   'text_to_ignore': []},
#  {'id': '1b59dbd1-e2fb-416e-91c9-f7de65432a3c',
#   'display': 'test/5.png',
#   'bbox': ['1250', '2872', '1836', '3010'],
#   'text': 'X453-8 Analog Out AMP2 2 P (DOOR FR)',
#   'text_to_ignore': []},
#  {'id': '2e40a111-a576-495e-b71c-87aa395d53ed',
#   'display': 'test/5.png',
#   'bbox': ['2076', '2978', '2642', '3048'],
#   'text': '~ TWIST AUDO9 A-A',
#   'text_to_ignore': []},
#  {'id': '4fe9ac66-6e29-41d9-b255-b1611904541d',
#   'display': 'test/5.png',
#   'bbox': ['1242', '3022', '1836', '3160'],
#   'text': 'X453-7 Analog Out AMP2 2 N (DOOR FR)',
#   'text_to_ignore': []},
#  {'id': 'c3337831-7797-4eea-b6ac-5e99e2fb09e5',
#   'display': 'test/5.png',
#   'bbox': ['1950', '3126', '2140', '3182'],
#   'text': 'X453',
#   'text_to_ignore': []},
#  {'id': 'cf7f3f9a-b12d-4357-bfd6-5ee4c892441a',
#   'display': 'test/5.png',
#   'bbox': ['1236', '3622', '1836', '3760'],
#   'text': 'X454-10 Analog Out AMP3 1 P (IP LEFT)',
#   'text_to_ignore': []},
#  {'id': '39c0f1ae-66bd-4209-86c2-15fb51b09f3d',
#   'display': 'test/5.png',
#   'bbox': ['2074', '3726', '2644', '3800'],
#   'text': '~ TWIST AUD30 A-C',
#   'text_to_ignore': []},
#  {'id': 'cb882b7c-4125-4514-b832-956537c48405',
#   'display': 'test/5.png',
#   'bbox': ['1265', '3779', '1836', '3912'],
#   'text': 'X454-9 Analog Out AMP3 1 N (IP LEFT)',
#   'text_to_ignore': []},
#  {'id': 'ddc37fb4-1419-4469-a32b-224ec1c1f026',
#   'display': 'test/5.png',
#   'bbox': ['3096', '2878', '3822', '3000'],
#   'text': 'AUDO9 A-A RD 0.50 FLRY 566 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '792570ab-9d0d-4383-9cd4-2dc7ef61e595',
#   'display': 'test/5.png',
#   'bbox': ['3096', '3030', '3818', '3152'],
#   'text': 'AUD10 A-A GY 0.50 FLRY 566 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '2d0af0b2-91cb-47bf-9de9-cbf0fb9b87df',
#   'display': 'test/5.png',
#   'bbox': ['3096', '3630', '3810', '3750'],
#   'text': 'AUD30 A-A YE 0.50 FLRY 586 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '3cd46eda-fcee-4c50-a55a-042d3fb3953a',
#   'display': 'test/5.png',
#   'bbox': ['3096', '3780', '3816', '3902'],
#   'text': 'AUD31 A-A VT 0.50 FLRY 586 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '15754a03-1704-4e9b-b945-7ea67f80b013',
#   'display': 'test/5.png',
#   'bbox': ['4356', '2978', '4918', '3048'],
#   'text': 'TWIST AUDO9 A-A',
#   'text_to_ignore': []},
#  {'id': '618924be-2969-40a8-b9c7-d8e41d48f089',
#   'display': 'test/5.png',
#   'bbox': ['4851', '3125', '5041', '3181'],
#   'text': 'X051)',
#   'text_to_ignore': []},
#  {'id': '5c91a507-d7c1-4a58-b64e-69dc5a2b9add',
#   'display': 'test/5.png',
#   'bbox': ['4355', '3724', '4920', '3800'],
#   'text': 'TWIST AUD30 A-C',
#   'text_to_ignore': []},
#  {'id': '69b20fc4-d752-4638-89a0-c55195a8aecb',
#   'display': 'test/5.png',
#   'bbox': ['5104', '2654', '8614', '2848'],
#   'text': 'Body Controller Right B,W,J,D XO50A B X051 X052 X054 X060A B X062 X053A B X055 X056 X058 X059',
#   'text_to_ignore': []},
#  {'id': 'e3b447e2-3134-4b36-b13e-cccf6af75931',
#   'display': 'test/5.png',
#   'bbox': ['5161', '2879', '7236', '3010'],
#   'text': 'X051-9 Pass-through X053B-10 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH P AUDIO FRONT DOOR 2 PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': '34125c3c-8233-4542-b77b-1c95ce141689',
#   'display': 'test/5.png',
#   'bbox': ['5162', '3032', '7236', '3160'],
#   'text': 'X051-10 Pass-through X053B-19 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH N AUDIO FRONT DOOR 2 PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': 'ea1604f3-43a7-4909-ab5d-65a6e0eeb83f',
#   'display': 'test/5.png',
#   'bbox': ['5162', '3629', '6012', '3760'],
#   'text': 'X051-13 Pass-through AUDIO LEFT IP PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': 'ec095eeb-804f-426d-89b4-3b9d52045da6',
#   'display': 'test/5.png',
#   'bbox': ['5161', '3780', '6018', '3910'],
#   'text': 'X051-14 Pass-through AUDIO LEFT IP PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': 'a7c7c196-ed16-44d1-b4cf-5690b8e89a80',
#   'display': 'test/5.png',
#   'bbox': ['7476', '2978', '8028', '3048'],
#   'text': 'TWIST AUDO9 B-E',
#   'text_to_ignore': []},
#  {'id': 'b2b90b1b-5d64-4ca9-bf4b-878a1c72ea46',
#   'display': 'test/5.png',
#   'bbox': ['7350', '3126', '7562', '3182'],
#   'text': 'X053B',
#   'text_to_ignore': []},
#  {'id': 'a8fd60cf-ac27-4808-90d7-92119bc431f8',
#   'display': 'test/5.png',
#   'bbox': ['6389', '3629', '7236', '3758'],
#   'text': 'X055-1 Pass-through AUDIO LEFT IP PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': '437f6140-fab5-45f3-b9a6-a5803d3ba93d',
#   'display': 'test/5.png',
#   'bbox': ['7474', '3726', '8028', '3800'],
#   'text': '~ TWIST AUD30 B-F',
#   'text_to_ignore': []},
#  {'id': 'f5b5d364-26e3-4cac-ba63-539d72f96cfd',
#   'display': 'test/5.png',
#   'bbox': ['6380', '3779', '7238', '3910'],
#   'text': 'X055-2 Pass-through AUDIO LEFT IP LPASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': 'a79a5f92-c866-4460-84d5-c1eb78113c7c',
#   'display': 'test/5.png',
#   'bbox': ['8164', '2878', '8896', '3000'],
#   'text': 'AUDO9 B-B WH 0.50 FLRY RHST 1601 2486398-XX (P)',
#   'text_to_ignore': []},
#  {'id': '32fd2d70-0877-41a3-8525-8accff48c00a',
#   'display': 'test/5.png',
#   'bbox': ['8163', '3029', '8882', '3150'],
#   'text': 'AUD10 B-B YE 0.50 FLRY RHST 1601 2486398-XX (P)',
#   'text_to_ignore': []},
#  {'id': '69d650c3-17c5-4fe8-b8ce-9cd5187e571b',
#   'display': 'test/5.png',
#   'bbox': ['8164', '3628', '8878', '3750'],
#   'text': 'AUD30 B-B GY 0.75 FLRY DRLH 629 3486401-XX (J)',
#   'text_to_ignore': []},
#  {'id': '89103cbe-fc67-4bf6-8b95-83d553571fe0',
#   'display': 'test/5.png',
#   'bbox': ['8162', '3778', '8880', '3902'],
#   'text': 'AUD31 B-B RD 0.75 FLRY DRLH 629 3486401-XX (J)',
#   'text_to_ignore': []},
#  {'id': '1d4d7564-2db5-44ae-bddd-96cb7f084c71',
#   'display': 'test/5.png',
#   'bbox': ['9824', '2863', '10106', '2925'],
#   'text': '- -X927F R',
#   'text_to_ignore': []},
#  {'id': '91f0ae77-ab99-4105-92ce-8c55d96b90b4',
#   'display': 'test/5.png',
#   'bbox': ['9478', '2864', '9768', '2926'],
#   'text': 'X927M R',
#   'text_to_ignore': []},
#  {'id': 'a1f99f54-d5c7-43c4-a79f-50f891ef4ab4',
#   'display': 'test/5.png',
#   'bbox': ['8942', '2978', '9768', '3074'],
#   'text': 'TWIST AUDO9 B-E h x927M R',
#   'text_to_ignore': []},
#  {'id': '71669278-b39d-4c9b-8610-d1c8e013ad79',
#   'display': 'test/5.png',
#   'bbox': ['9792', '3014', '10106', '3124'],
#   'text': 'X927F R Go',
#   'text_to_ignore': []},
#  {'id': 'e0e1dd34-39d6-4865-8ad7-9601235f7e40',
#   'display': 'test/5.png',
#   'bbox': ['9018', '3614', '10578', '3824'],
#   'text': 'aa X950F X950M 14 14 ; A - + yqgoq TWIST AUD30 B-E TWIST AUD30 B-F oso',
#   'text_to_ignore': []},
#  {'id': '646a43c4-50eb-4004-9c8d-631a53c91ba1',
#   'display': 'test/5.png',
#   'bbox': ['10189', '2878', '11548', '3152'],
#   'text': 'AUDO9 B-A WH 0.75 FLRY RHST 617.061553 1613836-XX (DT) TWIST AUDO9 B-D AUD10 B-A YE 0.75 FLRY RHST 617.061553 =1613836-XX (DT)',
#   'text_to_ignore': []},
#  {'id': 'df7f3683-116b-4785-8bd5-1a88d3c35e27',
#   'display': 'test/5.png',
#   'bbox': ['10674', '3630', '11412', '3750'],
#   'text': 'AUD30 B-A GY 0.75 FLRY DRLH 1828 2494925-XX (JT)',
#   'text_to_ignore': []},
#  {'id': 'cadc4f47-40c3-4e21-986d-8709b8b9f3c5',
#   'display': 'test/5.png',
#   'bbox': ['10674', '3778', '11414', '3902'],
#   'text': 'AUD31 B-A RD 0.75 FLRY DRLH 1828 2494925-XX (JT)',
#   'text_to_ignore': []},
#  {'id': '3daa2dd5-f11d-4bf8-be3d-5f3a395d886b',
#   'display': 'test/5.png',
#   'bbox': ['12377', '2665', '13482', '2840'],
#   'text': 'Speaker Door Front Fullrange DT X424',
#   'text_to_ignore': []},
#  {'id': '2c7014d1-0ba7-4465-b362-cee40cce4d1e',
#   'display': 'test/5.png',
#   'bbox': ['12435', '2880', '12936', '3012'],
#   'text': 'X424-1 Power In Speaker P',
#   'text_to_ignore': []},
#  {'id': 'ab8da6c0-6786-4b9b-9853-19faee522753',
#   'display': 'test/5.png',
#   'bbox': ['11630', '2978', '12192', '3050'],
#   'text': 'TWIST AUDO9 B-D',
#   'text_to_ignore': []},
#  {'id': '44632af2-a190-4634-821a-6f4c408ddac2',
#   'display': 'test/5.png',
#   'bbox': ['12436', '3030', '12936', '3162'],
#   'text': 'X424-2 Power In Speaker N',
#   'text_to_ignore': []},
#  {'id': '9a76baa2-41b1-401a-a768-35ddcdcc8c53',
#   'display': 'test/5.png',
#   'bbox': ['12128', '3126', '12320', '3182'],
#   'text': 'X424',
#   'text_to_ignore': []},
#  {'id': '1b83b859-1215-4db2-92e3-40c255a68f52',
#   'display': 'test/5.png',
#   'bbox': ['12376', '3416', '13072', '3590'],
#   'text': 'Speaker IP Left ST X416',
#   'text_to_ignore': []},
#  {'id': 'c8f393c6-3d89-4fcc-9d32-b42ebdfa03f3',
#   'display': 'test/5.png',
#   'bbox': ['12436', '3630', '12936', '3760'],
#   'text': 'X416-1 Power In Speaker P',
#   'text_to_ignore': []},
#  {'id': '059ee746-e2b7-4eab-8c32-b750d956682f',
#   'display': 'test/5.png',
#   'bbox': ['11641', '3724', '12194', '3800'],
#   'text': 'TWIST AUD30 B-E',
#   'text_to_ignore': []},
#  {'id': 'e93b1ffe-bf8e-4697-8d3d-9ea35049b46c',
#   'display': 'test/5.png',
#   'bbox': ['12435', '3779', '12936', '3910'],
#   'text': 'X416-2 Power In Speaker N',
#   'text_to_ignore': []},
#  {'id': '5cfca309-cb54-48cd-a6b2-666493e2e0ff',
#   'display': 'test/5.png',
#   'bbox': ['1948', '3876', '2144', '3932'],
#   'text': 'X454',
#   'text_to_ignore': []},
#  {'id': '0903850f-35b9-42af-9616-cfb23119759a',
#   'display': 'test/5.png',
#   'bbox': ['1230', '4298', '1836', '4436'],
#   'text': 'X453-16 Analog Out AMP2 4 P (CENTER IP)',
#   'text_to_ignore': []},
#  {'id': '05781074-bacf-4c92-b1f9-546aabca52b2',
#   'display': 'test/5.png',
#   'bbox': ['2076', '4402', '2644', '4474'],
#   'text': '~ TWIST AUD32 A-C',
#   'text_to_ignore': []},
#  {'id': 'd5fb8b1f-731f-456a-8d31-0a5a44528d88',
#   'display': 'test/5.png',
#   'bbox': ['1230', '4448', '1836', '4588'],
#   'text': 'X453-15 Analog Out AMP2 4 N (CENTER IP)',
#   'text_to_ignore': []},
#  {'id': '2b1c9adc-fa49-4b62-b4eb-34dae58a219c',
#   'display': 'test/5.png',
#   'bbox': ['1950', '4550', '2140', '4608'],
#   'text': 'X453',
#   'text_to_ignore': []},
#  {'id': '87a10bfc-f814-49ea-9b90-47b28a164e05',
#   'display': 'test/5.png',
#   'bbox': ['1264', '4972', '1836', '5110'],
#   'text': 'X454-7 Analog Out AMP3 3 P (IP RIGHT)',
#   'text_to_ignore': []},
#  {'id': 'a3a62db4-fed7-4adf-bf98-059c46d5ac0f',
#   'display': 'test/5.png',
#   'bbox': ['2072', '5078', '2632', '5144'],
#   'text': '~ TWIST AUD34 A-C',
#   'text_to_ignore': []},
#  {'id': 'acb6af06-215f-4f53-a95d-a4468a4f3439',
#   'display': 'test/5.png',
#   'bbox': ['3096', '4304', '3816', '4426'],
#   'text': 'AUD32 A-A VT 0.50 FLRY 566 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'ad4bd972-93c5-4fe0-851c-45c2a0062521',
#   'display': 'test/5.png',
#   'bbox': ['3096', '4454', '3828', '4576'],
#   'text': 'AUD33 A-A GN 0.50 FLRY 566 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '6d790d99-3a58-4727-a1c7-038b9967eabb',
#   'display': 'test/5.png',
#   'bbox': ['3095', '4977', '3820', '5102'],
#   'text': 'AUD34 A-A BU 0.50 FLRY 586 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'a91dc45f-21b9-41d3-b8c0-84bfcec8e610',
#   'display': 'test/5.png',
#   'bbox': ['4851', '3875', '5041', '3931'],
#   'text': 'X051)',
#   'text_to_ignore': []},
#  {'id': '7d7426b9-d26d-4ac6-aae1-0fc69c1c8987',
#   'display': 'test/5.png',
#   'bbox': ['4356', '4402', '4920', '4474'],
#   'text': 'TWIST AUD32 A-C',
#   'text_to_ignore': []},
#  {'id': 'c7d19ae1-cb06-4dff-b363-62a8046b4529',
#   'display': 'test/5.png',
#   'bbox': ['4851', '4551', '5041', '4607'],
#   'text': 'X051.',
#   'text_to_ignore': []},
#  {'id': '03078be9-221c-4bd5-8d6a-12d0ead0cdec',
#   'display': 'test/5.png',
#   'bbox': ['4354', '5076', '4918', '5144'],
#   'text': 'TWIST AUD34 A-C',
#   'text_to_ignore': []},
#  {'id': '75d0b9eb-52d5-4737-abff-b3df1107e56a',
#   'display': 'test/5.png',
#   'bbox': ['5162', '4304', '6084', '4432'],
#   'text': 'X051-11 Pass-through AUDIO CENTER IP PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': '46f34bc0-b8ec-4751-af38-10d8cef78064',
#   'display': 'test/5.png',
#   'bbox': ['6314', '4306', '7236', '4432'],
#   'text': 'X055-31 Pass-through AUDIO CENTER IP PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': 'bfb431cf-c59c-414c-93d4-388f2a9353e8',
#   'display': 'test/5.png',
#   'bbox': ['5162', '4455', '6094', '4582'],
#   'text': 'X051-12 Pass-through AUDIO CENTER IP PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': 'da26d1ad-c1bc-406d-b13a-d3ec0f8d1a8d',
#   'display': 'test/5.png',
#   'bbox': ['6304', '4456', '7236', '4582'],
#   'text': 'X055-32 Pass-through AUDIO CENTER IP PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': 'b3c9f235-ac08-4071-a8e8-21ee53fd8d76',
#   'display': 'test/5.png',
#   'bbox': ['5162', '4979', '6052', '5110'],
#   'text': 'X051-29 Pass-through AUDIO RIGHT IP PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': '23d3e21f-c95b-48af-abca-04de488bd171',
#   'display': 'test/5.png',
#   'bbox': ['7350', '3876', '7540', '3932'],
#   'text': 'X055',
#   'text_to_ignore': []},
#  {'id': '8e477c22-2f46-421c-b766-b66a2eb355db',
#   'display': 'test/5.png',
#   'bbox': ['7476', '4402', '8038', '4472'],
#   'text': 'TWIST AUD32 B-H',
#   'text_to_ignore': []},
#  {'id': '9611d814-2a06-473d-bc05-e639c8ea4f4e',
#   'display': 'test/5.png',
#   'bbox': ['7350', '4552', '7540', '4608'],
#   'text': 'iXO55',
#   'text_to_ignore': []},
#  {'id': '36dce2f8-d323-4b2d-8e71-81c42e6f9c43',
#   'display': 'test/5.png',
#   'bbox': ['6350', '4980', '7236', '5106'],
#   'text': 'X055-16 Pass-through AUDIO RIGHT IP PASSTHROUGH P',
#   'text_to_ignore': []},
#  {'id': 'a0555582-97d4-4d43-91ac-444f0e25b8eb',
#   'display': 'test/5.png',
#   'bbox': ['7472', '5078', '8028', '5144'],
#   'text': 'TWIST AUD34 B-F',
#   'text_to_ignore': []},
#  {'id': '97a8bbac-ecb2-413c-96da-bbfa40bbe74f',
#   'display': 'test/5.png',
#   'bbox': ['8162', '4304', '8888', '4426'],
#   'text': 'AUD32 B-B GN 0.75 FLRY DRLH 629 3486401-XX (J)',
#   'text_to_ignore': []},
#  {'id': '484c75c6-d984-4615-bad6-2de1e1b63ee3',
#   'display': 'test/5.png',
#   'bbox': ['8164', '4454', '8896', '4576'],
#   'text': 'AUD33 B-B WH 0.75 FLRY DRLH 629 3486401-XX (J)',
#   'text_to_ignore': []},
#  {'id': '7e9f36b6-df85-4880-b2d4-13a7aa758cf8',
#   'display': 'test/5.png',
#   'bbox': ['8162', '4978', '8872', '5102'],
#   'text': 'AUD34 B-B YE 0.50 FLRY DRLH 629 3486401-XX (J)',
#   'text_to_ignore': []},
#  {'id': '9281c4b5-66bb-40aa-9b02-3f580b3a861f',
#   'display': 'test/5.png',
#   'bbox': ['9680', '3830', '9920', '3878'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '9eed6663-1177-4d77-81cc-da4388fcc80f',
#   'display': 'test/5.png',
#   'bbox': ['9004', '4288', '11259', '4574'],
#   'text': 'AUD32 B-A GN 0.75 FLRY X950F X950M i 1) 1 DRLH 1099.0 2494925-xx (JT) TWIST AUD32 B-H hy Al L . TWIST AUD32 B-G [ X8S0F X950M AUD33 B-A WH 0.75 FLRY DRLH 1099.0 2494925-xXx (JT) 15 15 A A',
#   'text_to_ignore': []},
#  {'id': 'b1f23e3b-1224-486b-99b5-18fdc2d4bafa',
#   'display': 'test/5.png',
#   'bbox': ['9016', '4963', '11236', '5252'],
#   'text': '. X950F X950M AUD34 B-A YE 0.50 FLRY TWIST AUD34.8-F etl TWISTAUDM4 BE - —" " X950F" X950M 7 ~~ AUD35 B-A BU 0.50 FLRY 17 17 DRLH 352.0 2494925-XX UT)',
#   'text_to_ignore': []},
#  {'id': '3697af01-eab8-48a3-959f-497c56acc6d3',
#   'display': 'test/5.png',
#   'bbox': ['12124', '3860', '12320', '3918'],
#   'text': 'X416',
#   'text_to_ignore': []},
#  {'id': 'bc210bde-6046-411f-8e00-635d47a25746',
#   'display': 'test/5.png',
#   'bbox': ['12376', '4092', '13092', '4266'],
#   'text': 'Speaker IP Center JT X410',
#   'text_to_ignore': []},
#  {'id': '2943035a-96e8-48dd-91e6-ed6bdce489a7',
#   'display': 'test/5.png',
#   'bbox': ['12436', '4304', '12936', '4436'],
#   'text': 'X410-1 Power In Speaker P',
#   'text_to_ignore': []},
#  {'id': '0f60c443-0680-4219-9002-f50cec6b9524',
#   'display': 'test/5.png',
#   'bbox': ['11632', '4404', '12192', '4474'],
#   'text': 'TWIST AUD32 B-G',
#   'text_to_ignore': []},
#  {'id': 'd62f4b60-f690-4f26-bb27-8f4a2d6fe137',
#   'display': 'test/5.png',
#   'bbox': ['12435', '4456', '12936', '4588'],
#   'text': 'X410-2 Power In Speaker N',
#   'text_to_ignore': []},
#  {'id': '36a3c726-104a-4059-be0a-104c643e898d',
#   'display': 'test/5.png',
#   'bbox': ['12127', '4543', '12319', '4601'],
#   'text': 'X410',
#   'text_to_ignore': []},
#  {'id': 'ef8204b6-0801-4727-9dcc-77ff9ced0ced',
#   'display': 'test/5.png',
#   'bbox': ['12376', '4765', '13072', '4940'],
#   'text': 'Speaker IP Right ST X417',
#   'text_to_ignore': []},
#  {'id': '8fe50da1-fef5-4748-93f5-10a41ede78df',
#   'display': 'test/5.png',
#   'bbox': ['12435', '4980', '12936', '5112'],
#   'text': 'X417-1 Power In Speaker P',
#   'text_to_ignore': []},
#  {'id': '772981b5-9f17-41ed-a893-11246963c32d',
#   'display': 'test/5.png',
#   'bbox': ['11640', '5076', '12192', '5146'],
#   'text': 'TWIST AUD34 B-E',
#   'text_to_ignore': []},
#  {'id': '9be990fb-cd50-43fd-832c-576eebaabab4',
#   'display': 'test/5.png',
#   'bbox': ['12', '5712', '144', '5782'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '5cf64098-5b3f-4fa1-8d52-e523dc745452',
#   'display': 'test/5.png',
#   'bbox': ['1162', '5722', '1836', '5860'],
#   'text': 'X453-11 Analog Out AMP1 1 P (APILLAR LEFT)',
#   'text_to_ignore': []},
#  {'id': 'c6f15b5e-f9fd-4c71-bb66-2ab0f65da27a',
#   'display': 'test/5.png',
#   'bbox': ['1152', '5872', '1836', '6010'],
#   'text': 'X453-12 Analog Out AMP1 1 N (APILLAR LEFT)',
#   'text_to_ignore': []},
#  {'id': '5bf5e045-8ee8-4c76-bb64-4de112f9b68d',
#   'display': 'test/5.png',
#   'bbox': ['1256', '5122', '1838', '5260'],
#   'text': 'X454-8 Analog Out AMP3 3 N (IP RIGHT)',
#   'text_to_ignore': []},
#  {'id': 'bd08417c-344d-4135-ac02-b1054bca3afd',
#   'display': 'test/5.png',
#   'bbox': ['1950', '5226', '2144', '5282'],
#   'text': 'X454',
#   'text_to_ignore': []},
#  {'id': '817d8b76-cad3-4a83-a841-a9a71955d176',
#   'display': 'test/5.png',
#   'bbox': ['2074', '5828', '2584', '5898'],
#   'text': '~ TWIST AUD36-D',
#   'text_to_ignore': []},
#  {'id': '121ee516-7c6c-4f3f-b892-081b0b829134',
#   'display': 'test/5.png',
#   'bbox': ['1126', '6324', '1838', '6456'],
#   'text': 'X453-6 Analog Out AMP2 1 P (APILLAR RIGHT)',
#   'text_to_ignore': []},
#  {'id': '8bb5305c-e29e-46e2-8b3b-ade25ef5e635',
#   'display': 'test/5.png',
#   'bbox': ['3096', '5130', '3824', '5252'],
#   'text': 'AUD35 A-A BN 0.50 FLRY 586 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'bf0946ca-3dac-45f2-ba87-afe23eb44a25',
#   'display': 'test/5.png',
#   'bbox': ['2894', '5728', '3580', '5854'],
#   'text': 'AUD36-A GN 0.50 FLRY 871.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '9cef99c0-0109-4e54-848b-76776d742e4d',
#   'display': 'test/5.png',
#   'bbox': ['2894', '5877', '3570', '6002'],
#   'text': 'AUD37-A GY 0.50 FLRY 871.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '7cd88fff-8268-46a1-9101-8b428ffe0f1c',
#   'display': 'test/5.png',
#   'bbox': ['3534', '6326', '4212', '6450'],
#   'text': 'AUD38-B RD 0.50 FLRY 838.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '1b5df2d0-ec73-4dfc-810b-0d67e627b07e',
#   'display': 'test/5.png',
#   'bbox': ['4851', '5226', '5041', '5282'],
#   'text': 'X051.',
#   'text_to_ignore': []},
#  {'id': '064b490c-051b-4b4d-98d8-dd2c4762edda',
#   'display': 'test/5.png',
#   'bbox': ['4366', '5712', '4888', '5826'],
#   'text': 'X986F - X986M 11 1',
#   'text_to_ignore': []},
#  {'id': 'bc7afa4f-6407-42cb-a1a3-0d31eb46fdde',
#   'display': 'test/5.png',
#   'bbox': ['3884', '5828', '5344', '5976'],
#   'text': 'TWIST AUD36-D xoser © xesem TWIST AUD36-J oD 4 — 12 12',
#   'text_to_ignore': []},
#  {'id': '921d341b-fdda-4013-8a4c-99426cdf240a',
#   'display': 'test/5.png',
#   'bbox': ['5161', '5130', '6054', '5256'],
#   'text': 'X051-30 Pass-through AUDIO RIGHT IP PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': '3124147f-aa8d-4f29-a7f7-8adb23f79c14',
#   'display': 'test/5.png',
#   'bbox': ['5556', '5728', '6242', '5850'],
#   'text': 'AUD36-D GN 0.50 FLRY 1655.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': '80e1f004-2340-4150-934a-3b0ec02cd859',
#   'display': 'test/5.png',
#   'bbox': ['5556', '5877', '6234', '6000'],
#   'text': 'AUD37-D GY 0.50 FLRY 1655.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': 'b194c087-ebd5-4d44-ae43-19ef2f5002fd',
#   'display': 'test/5.png',
#   'bbox': ['5630', '6312', '5874', '6378'],
#   'text': 'X973M',
#   'text_to_ignore': []},
#  {'id': '306ff594-618c-4367-ae5f-8e5464055f01',
#   'display': 'test/5.png',
#   'bbox': ['5924', '6312', '6152', '6374'],
#   'text': 'X973F',
#   'text_to_ignore': []},
#  {'id': 'f0385cde-8f4b-4cf0-ae34-0dfca614b761',
#   'display': 'test/5.png',
#   'bbox': ['6350', '5129', '7234', '5256'],
#   'text': 'X055-15 Pass-through AUDIO RIGHT IP PASSTHROUGH N',
#   'text_to_ignore': []},
#  {'id': 'bd45248b-571e-47f8-a6bc-ac7196fb7e9e',
#   'display': 'test/5.png',
#   'bbox': ['7350', '5226', '7540', '5282'],
#   'text': "'X055",
#   'text_to_ignore': []},
#  {'id': '61e56d8e-4c9b-4a4b-bddf-5ded9dc25cea',
#   'display': 'test/5.png',
#   'bbox': ['6980', '5712', '7220', '5774'],
#   'text': 'X972M',
#   'text_to_ignore': []},
#  {'id': 'd133068e-f00f-4e18-959b-21787a14eb6c',
#   'display': 'test/5.png',
#   'bbox': ['7274', '5714', '7502', '5774'],
#   'text': 'X972F',
#   'text_to_ignore': []},
#  {'id': 'd02e1911-35ef-4f75-9dc0-23845e90ba83',
#   'display': 'test/5.png',
#   'bbox': ['6527', '5827', '7974', '5974'],
#   'text': '- TWIST AUD36-J xe72M af - XO72F TWIST AUD36-E — 2 2 —',
#   'text_to_ignore': []},
#  {'id': 'a86242bf-819f-4c90-af2f-cf895b4ff80b',
#   'display': 'test/5.png',
#   'bbox': ['7544', '6328', '8298', '6450'],
#   'text': 'AUD38-A RD 0.50 FLRY 422.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '0d537d52-99ec-4c7c-89ce-b2c31268ba5f',
#   'display': 'test/5.png',
#   'bbox': ['8164', '5130', '8880', '5252'],
#   'text': 'AUD35 B-B BU 0.50 FLRY DRLH 629 3486401-XX (J)',
#   'text_to_ignore': []},
#  {'id': 'f52e5b6e-fde2-4d3a-be98-69cae024401a',
#   'display': 'test/5.png',
#   'bbox': ['8219', '5726', '8970', '5850'],
#   'text': 'AUD36-B GN 0.50 FLRY 402.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '810ba2d5-cd92-4528-851e-95ba3cb931b2',
#   'display': 'test/5.png',
#   'bbox': ['8218', '5877', '8970', '6000'],
#   'text': 'AUD37-B GY 0.50 FLRY 402.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': 'd4baa18a-4084-49d1-bfe6-e1971752d6d0',
#   'display': 'test/5.png',
#   'bbox': ['9978', '5517', '11290', '5692'],
#   'text': 'Speaker A-Pillar Lower Left Tweeter AT X450',
#   'text_to_ignore': []},
#  {'id': '4f7d669b-c238-4a5a-b391-0466c663ff5d',
#   'display': 'test/5.png',
#   'bbox': ['10036', '5728', '10558', '5860'],
#   'text': 'X450-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': 'bbe7dd2e-46d5-470f-b41f-2a4e70aa20d7',
#   'display': 'test/5.png',
#   'bbox': ['9294', '5827', '9794', '5898'],
#   'text': 'TWIST AUD36-E',
#   'text_to_ignore': []},
#  {'id': '234f27b3-7909-4235-b008-3dae3e49f24e',
#   'display': 'test/5.png',
#   'bbox': ['10031', '5872', '10560', '6020'],
#   'text': 'X450-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': '45f6d4c4-7794-4266-bdc2-bd3867c4cf8d',
#   'display': 'test/5.png',
#   'bbox': ['9728', '5946', '9920', '6002'],
#   'text': 'X450!',
#   'text_to_ignore': []},
#  {'id': '8c2e33c3-c727-405c-bc9a-f2ba8a1b984f',
#   'display': 'test/5.png',
#   'bbox': ['9977', '6117', '11340', '6288'],
#   'text': 'Speaker A-Pillar Lower Right Tweeter AT X451',
#   'text_to_ignore': []},
#  {'id': '6bc79f51-c18e-45fb-83b6-e45a03787ac8',
#   'display': 'test/5.png',
#   'bbox': ['10035', '6326', '10560', '6459'],
#   'text': 'X451-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': '31158f6e-bf9b-463b-ab5c-3a16e3245969',
#   'display': 'test/5.png',
#   'bbox': ['12436', '5130', '12938', '5260'],
#   'text': 'X417-2 Power In Speaker N',
#   'text_to_ignore': []},
#  {'id': 'a3d38e68-6092-414f-b904-6432bc41c642',
#   'display': 'test/5.png',
#   'bbox': ['12126', '5226', '12320', '5282'],
#   'text': 'X417',
#   'text_to_ignore': []},
#  {'id': '9feaa792-07f1-4b8a-a9b2-d53c6ba7edfd',
#   'display': 'test/5.png',
#   'bbox': ['1114', '6472', '1836', '6614'],
#   'text': 'X453-5 Analog Out AMP2 1 N (APILLAR RIGHT)',
#   'text_to_ignore': []},
#  {'id': '84a3ffe5-2653-4e22-a03a-b00ddb5ee1b1',
#   'display': 'test/5.png',
#   'bbox': ['1136', '6922', '1837', '7061'],
#   'text': 'X454-4 Analog Out AMP3 2 P (HEADLINER FL)',
#   'text_to_ignore': []},
#  {'id': 'cb3cb1e1-2def-4571-b463-331c60616a1b',
#   'display': 'test/5.png',
#   'bbox': ['1130', '7072', '1836', '7213'],
#   'text': 'X454-3 Analog Out AMP3 2 N (HEADLINER FL)',
#   'text_to_ignore': []},
#  {'id': 'dab2b8bd-bd40-47a8-a4f5-85ab3a48ca5e',
#   'display': 'test/5.png',
#   'bbox': ['8', '7326', '144', '7398'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': 'b66d06f7-ca6d-44f0-9dd3-c3625a180c2b',
#   'display': 'test/5.png',
#   'bbox': ['1134', '7524', '1838', '7660'],
#   'text': 'X453-1 Analog Out AMP1 4 P (HEADLINER FR)',
#   'text_to_ignore': []},
#  {'id': 'dccb48ad-7694-4402-bf29-48a1cd992ca9',
#   'display': 'test/5.png',
#   'bbox': ['2074', '6428', '2576', '6498'],
#   'text': '~ TWIST AUD38-B',
#   'text_to_ignore': []},
#  {'id': 'e5c0af79-fde9-4cb0-9709-da92e87e6423',
#   'display': 'test/5.png',
#   'bbox': ['1947', '6575', '2139', '6631'],
#   'text': 'X453',
#   'text_to_ignore': []},
#  {'id': 'f76bba13-a4ed-4e28-ace2-cca8c0319b52',
#   'display': 'test/5.png',
#   'bbox': ['2074', '7028', '2584', '7098'],
#   'text': 'TWIST AUD40-D',
#   'text_to_ignore': []},
#  {'id': '21142004-1265-4639-81e1-5dea27e8a4dc',
#   'display': 'test/5.png',
#   'bbox': ['1950', '7176', '2144', '7232'],
#   'text': 'X454',
#   'text_to_ignore': []},
#  {'id': 'e1ad0e12-79ad-4666-8b59-e9df16500541',
#   'display': 'test/5.png',
#   'bbox': ['2144', '7626', '2646', '7700'],
#   'text': 'TWIST AUD42-B',
#   'text_to_ignore': []},
#  {'id': 'b167633f-928b-4ae2-947d-0cb4f1948029',
#   'display': 'test/5.png',
#   'bbox': ['3533', '6479', '4224', '6602'],
#   'text': 'AUD39-B WH 0.50 FLRY 838.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'e0f2359e-105e-4c3e-8100-e88d68419514',
#   'display': 'test/5.png',
#   'bbox': ['2894', '6928', '3574', '7052'],
#   'text': 'AUD40-A RD 0.50 FLRY 891.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'b3258236-682f-417b-ab6b-db2939d76953',
#   'display': 'test/5.png',
#   'bbox': ['2894', '7078', '3568', '7200'],
#   'text': 'AUD41-A BK 0.50 FLRY 891.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '88d0b4f5-0e1f-4eb6-b28b-a550ab3c6603',
#   'display': 'test/5.png',
#   'bbox': ['3534', '7526', '4208', '7652'],
#   'text': 'AUD42-B BU 0.50 FLRY 858 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'e0c639b3-036f-4084-ad72-c446cfaf8356',
#   'display': 'test/5.png',
#   'bbox': ['4650', '6912', '4888', '6976'],
#   'text': '~ X986M',
#   'text_to_ignore': []},
#  {'id': '4bedb70c-8b21-4347-b163-c96d6913e4d7',
#   'display': 'test/5.png',
#   'bbox': ['4366', '6914', '4594', '6974'],
#   'text': 'X986F',
#   'text_to_ignore': []},
#  {'id': '11381754-e105-4d9c-8dfa-2a918a37bd4d',
#   'display': 'test/5.png',
#   'bbox': ['3884', '7027', '5342', '7176'],
#   'text': 'TWIST AUD40-D TWIST AUD40-J XO86F XO86M 10 10',
#   'text_to_ignore': []},
#  {'id': 'a50d6279-6304-4ed0-989b-bd9e286e9e6a',
#   'display': 'test/5.png',
#   'bbox': ['5166', '6430', '6630', '6576'],
#   'text': 'TWIST AUD38-B gran, yg7gp TWIST AUD38-C 2 2',
#   'text_to_ignore': []},
#  {'id': '6505b8fe-2343-43ed-8070-b3e3c1f13652',
#   'display': 'test/5.png',
#   'bbox': ['5556', '6928', '6236', '7048'],
#   'text': 'AUD40-D RD 0.50 FLRY 1655.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': '87804be4-b56a-4cf2-af57-fbe92fb67f78',
#   'display': 'test/5.png',
#   'bbox': ['5556', '7078', '6232', '7200'],
#   'text': 'AUD41-D BK 0.50 FLRY 1655.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': '0901687e-83fc-4485-80ab-db56bfb255f0',
#   'display': 'test/5.png',
#   'bbox': ['5894', '7512', '6152', '7618'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '3d4dc928-1598-43ba-ace1-a24295ae892b',
#   'display': 'test/5.png',
#   'bbox': ['5629', '7513', '5869', '7573'],
#   'text': 'X973M(',
#   'text_to_ignore': []},
#  {'id': 'b4f5158e-2db4-4643-93c6-f565cc50375a',
#   'display': 'test/5.png',
#   'bbox': ['5174', '7626', '5872', '7728'],
#   'text': '-Bo L TWIST AUD42-B xo7aM 7',
#   'text_to_ignore': []},
#  {'id': 'af5f2c89-7e6d-47c3-9f14-9aece7356b96',
#   'display': 'test/5.png',
#   'bbox': ['5924', '7626', '6632', '7724'],
#   'text': '+ KO73E TWIST AUD42-C',
#   'text_to_ignore': []},
#  {'id': 'f224852b-0efe-4ce7-8b53-00824d361064',
#   'display': 'test/5.png',
#   'bbox': ['7542', '6478', '8300', '6600'],
#   'text': 'AUD39-A WH 0.50 FLRY 422.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '078154a5-29ec-43b5-b810-33d29e12783d',
#   'display': 'test/5.png',
#   'bbox': ['6980', '6912', '7220', '6974'],
#   'text': 'X972M(',
#   'text_to_ignore': []},
#  {'id': 'db59a041-cffc-46db-9582-a40ec967b913',
#   'display': 'test/5.png',
#   'bbox': ['7242', '6914', '7502', '7024'],
#   'text': 'X972F',
#   'text_to_ignore': []},
#  {'id': 'de610b2e-2155-4f71-aaf6-4cc6ef2e40e8',
#   'display': 'test/5.png',
#   'bbox': ['6527', '7027', '7217', '7123'],
#   'text': 'TWIST AUD40-J orang 7',
#   'text_to_ignore': []},
#  {'id': 'aa04b3db-937c-43cc-8041-f731f0fb5f60',
#   'display': 'test/5.png',
#   'bbox': ['7276', '7026', '7974', '7124'],
#   'text': "' TWIST AUD40-E X972F ,",
#   'text_to_ignore': []},
#  {'id': '604cb1b5-80eb-475a-917f-e412f6fa8186',
#   'display': 'test/5.png',
#   'bbox': ['7542', '7526', '8300', '7650'],
#   'text': 'AUD42-A BU 0.50 FLRY 531.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '3704db23-387e-4e24-9263-9c736661c140',
#   'display': 'test/5.png',
#   'bbox': ['8220', '6926', '8971', '7050'],
#   'text': 'AUD40-B RD 0.50 FLRY 511.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '0387ff99-0c28-4e44-ba3c-19e999ade7d4',
#   'display': 'test/5.png',
#   'bbox': ['8218', '7078', '8970', '7200'],
#   'text': 'AUD41-B) BK 0.50 FLRY 511.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '47ca85d1-b244-431d-9dba-32c02fec8f98',
#   'display': 'test/5.png',
#   'bbox': ['9288', '6430', '9794', '6498'],
#   'text': 'TWIST AUD38-C',
#   'text_to_ignore': []},
#  {'id': '89ac5915-9e23-4cdf-9693-a4cc8a6da610',
#   'display': 'test/5.png',
#   'bbox': ['10035', '6472', '10560', '6611'],
#   'text': 'X451-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': 'b93538b6-84d5-447c-82b8-ab09b5eea0e2',
#   'display': 'test/5.png',
#   'bbox': ['9726', '6546', '9916', '6602'],
#   'text': 'X451',
#   'text_to_ignore': []},
#  {'id': 'b3f710cd-a1e3-4d75-84cf-5b07f70d7c48',
#   'display': 'test/5.png',
#   'bbox': ['9978', '6717', '10798', '6888'],
#   'text': 'Speaker Headliner FL AT X443',
#   'text_to_ignore': []},
#  {'id': '96311ca5-0b33-4fb6-91d7-44e3a199f457',
#   'display': 'test/5.png',
#   'bbox': ['10036', '6928', '10558', '7060'],
#   'text': 'X443-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': '9f2e603a-8de1-4e3a-8d75-c95b8bcdc262',
#   'display': 'test/5.png',
#   'bbox': ['9294', '7028', '9794', '7098'],
#   'text': 'TWIST AUD40-E',
#   'text_to_ignore': []},
#  {'id': 'c86f42c3-fc44-477c-baca-fe666a28d022',
#   'display': 'test/5.png',
#   'bbox': ['10031', '7072', '10560', '7220'],
#   'text': 'X443-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': 'fb4bb2ef-48f9-4adf-80e1-0fe3dcdd61e7',
#   'display': 'test/5.png',
#   'bbox': ['9728', '7146', '9918', '7202'],
#   'text': 'X443',
#   'text_to_ignore': []},
#  {'id': '0207e089-66ec-4de4-bfb7-a30bcf831da0',
#   'display': 'test/5.png',
#   'bbox': ['9977', '7316', '10809', '7488'],
#   'text': 'Speaker Headliner FR AT X444',
#   'text_to_ignore': []},
#  {'id': 'c7361da5-ad0b-455a-9ae4-059634315536',
#   'display': 'test/5.png',
#   'bbox': ['10035', '7526', '10558', '7664'],
#   'text': 'X444-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': 'a1ff3dea-3339-4a79-81ed-cb8774b13308',
#   'display': 'test/5.png',
#   'bbox': ['9290', '7626', '9796', '7702'],
#   'text': 'TWIST AUD42-C',
#   'text_to_ignore': []},
#  {'id': '0b1eb8af-0c44-4c60-83f8-9d290731850b',
#   'display': 'test/5.png',
#   'bbox': ['13902', '7330', '14032', '7390'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '9abcd6ab-27c5-4717-b705-6b0b8fd922cb',
#   'display': 'test/5.png',
#   'bbox': ['1122', '7674', '1836', '7815'],
#   'text': 'X453-2 Analog Out AMP1 4 N (HEADLINER FR)',
#   'text_to_ignore': []},
#  {'id': 'c8460f7e-ec6d-45ee-bdd6-c6ae170f7697',
#   'display': 'test/5.png',
#   'bbox': ['1133', '8048', '1836', '8184'],
#   'text': 'X453-3 Analog Out AMP1 3 P (HEADLINER RL)',
#   'text_to_ignore': []},
#  {'id': '176f2a7f-dcd6-45cf-8156-c573963aa403',
#   'display': 'test/5.png',
#   'bbox': ['1124', '8196', '1837', '8338'],
#   'text': 'X453-4 Analog Out AMP 1 3 N (HEADLINER RL)',
#   'text_to_ignore': []},
#  {'id': '849bee65-e538-40a0-b788-f228d0fe97b1',
#   'display': 'test/5.png',
#   'bbox': ['1128', '8570', '1836', '8708'],
#   'text': 'X453-14 Analog Out AMP2 3 P (HEADLINER RR)',
#   'text_to_ignore': []},
#  {'id': '2a3278a3-d848-4c6e-98e0-c3a7fba1f79e',
#   'display': 'test/5.png',
#   'bbox': ['1118', '8722', '1836', '8860'],
#   'text': 'X453-13 Analog Out AMP2 3 N (HEADLINER RR)',
#   'text_to_ignore': []},
#  {'id': 'be1c09ba-ed3f-4edd-a911-b028a6338b26',
#   'display': 'test/5.png',
#   'bbox': ['2074', '8152', '2582', '8222'],
#   'text': 'TWIST AUD50-A',
#   'text_to_ignore': []},
#  {'id': 'da7492db-2fd3-4558-8c53-1ad24a1a23ec',
#   'display': 'test/5.png',
#   'bbox': ['2074', '8678', '2580', '8748'],
#   'text': 'TWIST AUD52-A',
#   'text_to_ignore': []},
#  {'id': '6867ddef-3e46-4e83-89b9-1012f934d6ed',
#   'display': 'test/5.png',
#   'bbox': ['1950', '8826', '2140', '8882'],
#   'text': 'X453',
#   'text_to_ignore': []},
#  {'id': '8086f955-728b-42c3-bd62-cfeaed860a3a',
#   'display': 'test/5.png',
#   'bbox': ['3534', '7678', '4216', '7800'],
#   'text': 'AUD43-B GN 0.50 FLRY 858 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '8d84ca90-f860-4830-9784-e8ba6c61a9c5',
#   'display': 'test/5.png',
#   'bbox': ['2894', '8052', '3572', '8174'],
#   'text': 'AUD50-A BU 0.75 FLRY 871.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '7fbc0a8f-814c-47ad-aa97-35bc7d302fad',
#   'display': 'test/5.png',
#   'bbox': ['2896', '8204', '3574', '8324'],
#   'text': 'AUD51-A BN 0.75 FLRY 871.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '2088e8be-75ee-45fe-8f60-2e53017cb74e',
#   'display': 'test/5.png',
#   'bbox': ['2894', '8578', '3562', '8700'],
#   'text': 'AUD52-A YE 0.75 FLRY 871.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': '1e1aa7c5-f1f4-4c9d-b392-a15a371eca32',
#   'display': 'test/5.png',
#   'bbox': ['2896', '8728', '3576', '8850'],
#   'text': 'AUD53-A BN 0.75 FLRY 871.0 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'fce00dbe-b82d-4df8-8e48-05c22b93abcc',
#   'display': 'test/5.png',
#   'bbox': ['4366', '8038', '4594', '8100'],
#   'text': 'X986F',
#   'text_to_ignore': []},
#  {'id': '59f508c5-ce12-47ce-90db-b60be1659978',
#   'display': 'test/5.png',
#   'bbox': ['4648', '8038', '4888', '8100'],
#   'text': '- X986M',
#   'text_to_ignore': []},
#  {'id': '2cefa5df-73e3-4393-b079-0ae4ac23680f',
#   'display': 'test/5.png',
#   'bbox': ['3888', '8152', '4594', '8250'],
#   'text': 'TWIST AUDSO-A ogee',
#   'text_to_ignore': []},
#  {'id': '2016c296-44c0-47da-8572-60d81fbccdb4',
#   'display': 'test/5.png',
#   'bbox': ['4618', '8152', '5352', '8296'],
#   'text': '1 xo86M TWIST AUDS5O0-E 2',
#   'text_to_ignore': []},
#  {'id': 'd05db741-084e-406f-9e05-427f3d4dcd12',
#   'display': 'test/5.png',
#   'bbox': ['4366', '8562', '4888', '8674'],
#   'text': 'X986F - X986M > H o',
#   'text_to_ignore': []},
#  {'id': 'a69b89ba-6746-4894-90be-4a1045b74695',
#   'display': 'test/5.png',
#   'bbox': ['3888', '8678', '4594', '8774'],
#   'text': 'TWIST AUDS2-A ogee',
#   'text_to_ignore': []},
#  {'id': '8d5964cb-999b-442c-8935-cacfff2b147b',
#   'display': 'test/5.png',
#   'bbox': ['4650', '8678', '5350', '8771'],
#   'text': 'xo86M h TWIST AUD52-E',
#   'text_to_ignore': []},
#  {'id': '7bc58c65-11cc-4d0e-b526-0dc272f9bafc',
#   'display': 'test/5.png',
#   'bbox': ['5558', '8052', '6232', '8172'],
#   'text': 'AUD50-B BU 0.75 FLRY 1642.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': 'a7915b61-4476-425c-863d-c72cd3163a89',
#   'display': 'test/5.png',
#   'bbox': ['5558', '8201', '6234', '8324'],
#   'text': 'AUD51-B BN 0.75 FLRY 1642.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': '9c8765d5-a77f-411e-ba52-a615494c894d',
#   'display': 'test/5.png',
#   'bbox': ['5558', '8576', '6224', '8698'],
#   'text': 'AUD52-B) YE 0.75 FLRY 1642.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': 'c6118a66-fd0b-4a14-8c10-a827d86efdc9',
#   'display': 'test/5.png',
#   'bbox': ['5558', '8728', '6234', '8848'],
#   'text': 'AUD53-B BN 0.75 FLRY 1642.0 3486394-XX (A)',
#   'text_to_ignore': []},
#  {'id': '689898b3-ab33-4179-95c1-5d8edce4acd7',
#   'display': 'test/5.png',
#   'bbox': ['7542', '7678', '8301', '7800'],
#   'text': 'AUD43-A GN 0.50 FLRY 531.0 1617078-XX (AT)',
#   'text_to_ignore': []},
#  {'id': '24a7f3e4-61bc-4534-b9c5-d8e53745eba1',
#   'display': 'test/5.png',
#   'bbox': ['6982', '8037', '7502', '8150'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '6489ab4f-fd8d-44d4-8722-b2a9dee1427f',
#   'display': 'test/5.png',
#   'bbox': ['6520', '8152', '7984', '8300'],
#   'text': 'TWIST AUD50-E “xoam Ty ~xgear TWIST AUDSO-D 26 26',
#   'text_to_ignore': []},
#  {'id': '31fdbb26-0b29-4905-8119-772b6aba0054',
#   'display': 'test/5.png',
#   'bbox': ['6980', '8562', '7220', '8624'],
#   'text': 'X968M',
#   'text_to_ignore': []},
#  {'id': '331a7f16-8ed6-4f41-bb1a-ce19306dd4fd',
#   'display': 'test/5.png',
#   'bbox': ['7276', '8562', '7504', '8624'],
#   'text': 'X968F',
#   'text_to_ignore': []},
#  {'id': '64c5f26b-7ec3-4f1a-bffe-d030c12da9f7',
#   'display': 'test/5.png',
#   'bbox': ['6520', '8678', '7984', '8826'],
#   'text': 'TWIST AUD52-E “xooen gat , TWIST AUDS2-D 15 15',
#   'text_to_ignore': []},
#  {'id': '9e43470b-efc8-4d2f-ad3a-9c4448e667bf',
#   'display': 'test/5.png',
#   'bbox': ['8220', '8052', '8896', '8174'],
#   'text': 'AUD50-A BU 0.75 FLRY 1663.0 3486403-XX (K)',
#   'text_to_ignore': []},
#  {'id': 'e21148b7-1476-4a71-89a0-83dd16892ffc',
#   'display': 'test/5.png',
#   'bbox': ['8220', '8201', '8898', '8324'],
#   'text': 'AUD51-A BN 0.75 FLRY 1663.0 3486403-XX (K)',
#   'text_to_ignore': []},
#  {'id': '79ba037b-edbc-48ee-960d-1323c914dc95',
#   'display': 'test/5.png',
#   'bbox': ['8218', '8578', '8888', '8700'],
#   'text': 'AUD52-A YE 0.75 FLRY 2817.0 3486403-XX (K)',
#   'text_to_ignore': []},
#  {'id': '2c8675e3-df98-46f6-8534-74cbda2468e2',
#   'display': 'test/5.png',
#   'bbox': ['8220', '8728', '8898', '8850'],
#   'text': 'AUD53-A BN 0.75 FLRY 2817.0 3486403-XX (K)',
#   'text_to_ignore': []},
#  {'id': '01da3934-aadd-4e86-879a-748a51a8ac0d',
#   'display': 'test/5.png',
#   'bbox': ['10031', '7671', '10558', '7820'],
#   'text': 'X444-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': '0174aed5-8485-4028-a642-285fbae17ebf',
#   'display': 'test/5.png',
#   'bbox': ['9726', '7746', '9920', '7802'],
#   'text': 'X444)',
#   'text_to_ignore': []},
#  {'id': '2f701c1b-09e9-411b-8224-58aaaed33316',
#   'display': 'test/5.png',
#   'bbox': ['9979', '7842', '10804', '8012'],
#   'text': 'Speaker Headliner RL K X441',
#   'text_to_ignore': []},
#  {'id': '9f431c7d-af95-43be-ba77-a91fda0191ef',
#   'display': 'test/5.png',
#   'bbox': ['10036', '8047', '10558', '8186'],
#   'text': 'X441-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': '071b1208-ee00-4333-897f-c27343180e18',
#   'display': 'test/5.png',
#   'bbox': ['9281', '8152', '9792', '8224'],
#   'text': 'TWIST AUD50-D',
#   'text_to_ignore': []},
#  {'id': '768cbcd5-7c8a-470c-974d-058446eedb8f',
#   'display': 'test/5.png',
#   'bbox': ['10035', '8196', '10558', '8337'],
#   'text': 'X441-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': 'c606f0c7-b3fd-46fe-9d9a-279d9d5c2968',
#   'display': 'test/5.png',
#   'bbox': ['9727', '8268', '9917', '8328'],
#   'text': 'x441!',
#   'text_to_ignore': []},
#  {'id': '833ab042-592b-48e6-80c4-84ea7ff7c92c',
#   'display': 'test/5.png',
#   'bbox': ['9979', '8366', '10816', '8538'],
#   'text': 'Speaker Headliner RR K X442',
#   'text_to_ignore': []},
#  {'id': '15c224e3-abdf-4d64-9cce-300cc4c5cdd4',
#   'display': 'test/5.png',
#   'bbox': ['10036', '8570', '10556', '8712'],
#   'text': 'X442-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': 'a4b05e5a-0d8b-454f-a9d6-4260f7fa2ebd',
#   'display': 'test/5.png',
#   'bbox': ['9284', '8678', '9792', '8748'],
#   'text': 'TWIST AUD52-D',
#   'text_to_ignore': []},
#  {'id': 'a079abf3-fb96-4f19-b290-08834da38ee1',
#   'display': 'test/5.png',
#   'bbox': ['10036', '8722', '10558', '8862'],
#   'text': 'X442-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': '5091204a-82bb-4216-a180-8e26b4205a72',
#   'display': 'test/5.png',
#   'bbox': ['9728', '8796', '9918', '8852'],
#   'text': 'X442',
#   'text_to_ignore': []},
#  {'id': 'e0933047-1a12-46e4-9d11-11527daa9ef8',
#   'display': 'test/5.png',
#   'bbox': ['12713', '8292', '13112', '8432'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '2d2475af-a2ae-4b68-9b72-09bf245c50d5',
#   'display': 'test/5.png',
#   'bbox': ['12322', '8300', '12474', '8412'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '909425fa-92ea-4ec7-a887-0fd3bd961a90',
#   'display': 'test/5.png',
#   'bbox': ['11668', '8611', '13880', '8738'],
#   'text': 'THE INFORMATION CONTAINED HEREIN IS DEEMED TO BE CONFIDENTIAL, PROPRIETARY, AND A TRADE SECRET OF TESLA MOTORS. THIS INFORMATION MAY NOT BE USED, REPRODUCED, OR DISCLOSED AS THE DIRECT OR INDIRECT BASIS FOR THE DEVELOPMENT, MANUFACTURE, OR SALE OF PROCESSES OR PRODUCTS WITHOUT THE EXPRESSD WRITTEN CONSENT OF TESLA MOTORS.',
#   'text_to_ignore': []},
#  {'id': 'b697c8e5-d847-4307-b2ba-3a351b2b7fed',
#   'display': 'test/5.png',
#   'bbox': ['12623', '8762', '12981', '8841'],
#   'text': 'CHECKED',
#   'text_to_ignore': []},
#  {'id': 'cf3b4ddd-4dc4-4cf7-9b6c-efe5e8a93a12',
#   'display': 'test/5.png',
#   'bbox': ['11912', '8765', '12194', '8837'],
#   'text': 'DRAWN',
#   'text_to_ignore': []},
#  {'id': '2d5952f4-dbd2-4917-9cd6-a329190d5901',
#   'display': 'test/5.png',
#   'bbox': ['12750', '7670', '12850', '7690'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '5dabd4a9-5f8d-48be-a581-7d309eb112bd',
#   'display': 'test/5.png',
#   'bbox': ['13358', '8764', '13746', '8838'],
#   'text': 'APPROVED',
#   'text_to_ignore': []},
#  {'id': '6abcfaf6-e67d-4417-ac96-818b9119d06d',
#   'display': 'test/5.png',
#   'bbox': ['255', '9873', '582', '9946'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': 'd9a6d941-a2cb-4044-b0ae-3c67a63d1b89',
#   'display': 'test/5.png',
#   'bbox': ['1950', '9160', '3626', '9556'],
#   'text': 'X454 upsized for SuperHorn TWIST AUD44 A-C +AUD44 A-C BU 0.75 FLRY PSPK 544 3486395-XX (B) +AUD45 A-C WH 0.75 FLRY PSPK 544 3486395-XX (B)',
#   'text_to_ignore': []},
#  {'id': 'f5598470-1902-4c43-8886-ca13bf231bbb',
#   'display': 'test/5.png',
#   'bbox': ['1236', '9247', '1836', '9384'],
#   'text': 'X454-13 Analog Out AMP3 4 P (PSPK)',
#   'text_to_ignore': []},
#  {'id': 'bb2211cc-4430-4d28-8885-dd5a2e2fb5e3',
#   'display': 'test/5.png',
#   'bbox': ['1236', '9396', '1838', '9537'],
#   'text': 'X454-14 Analog Out AMP3 4 N (PSPK)',
#   'text_to_ignore': []},
#  {'id': 'a1b1b70a-e06f-4eb1-95d6-6167cccbd56f',
#   'display': 'test/5.png',
#   'bbox': ['3838', '9238', '5411', '9502'],
#   'text': 'X978F( X978M 10 10 TWIST AUD44 A-C x978F -X978M TWIST AUD44 A-B 20 20',
#   'text_to_ignore': []},
#  {'id': '8665498c-70ff-4583-9d00-360af908d4ec',
#   'display': 'test/5.png',
#   'bbox': ['5526', '9254', '6270', '9374'],
#   'text': '+AUD44 A-B BU 0.75 FLRY PSPK 2155 3486408-XX (W)',
#   'text_to_ignore': []},
#  {'id': 'c6c6a21a-5980-4134-8d2a-73e13a44581e',
#   'display': 'test/5.png',
#   'bbox': ['5524', '9401', '6288', '9526'],
#   'text': '+AUD45 A-B WH 0.75 FLRY PSPK 2155 3486408-XX (W)',
#   'text_to_ignore': []},
#  {'id': 'e648a7b2-867b-4712-9a57-6b03b2694311',
#   'display': 'test/5.png',
#   'bbox': ['5712', '9838', '5824', '9876'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '8282bccd-3d3d-40a8-b77c-8bf829b827eb',
#   'display': 'test/5.png',
#   'bbox': ['6980', '9236', '7220', '9298'],
#   'text': 'X964M (',
#   'text_to_ignore': []},
#  {'id': 'bd57fe1f-53c9-4da8-94c9-ee1bca1d4009',
#   'display': 'test/5.png',
#   'bbox': ['7274', '9238', '7504', '9298'],
#   'text': 'X964F',
#   'text_to_ignore': []},
#  {'id': 'de4c7c8b-d9a3-4575-84da-1a906f7b644d',
#   'display': 'test/5.png',
#   'bbox': ['6458', '9350', '8040', '9502'],
#   'text': 'TWIST AUD44 A-B “xoeam xO64F TWIST AUD44 A-A — 10110 —',
#   'text_to_ignore': []},
#  {'id': 'b7a8817e-bd66-4f9d-94ae-affebd047da2',
#   'display': 'test/5.png',
#   'bbox': ['8186', '9254', '8934', '9376'],
#   'text': '+AUD44 A-A BU 0.75 FLRY PSPK 1000.0 3507992-Xx (F)',
#   'text_to_ignore': []},
#  {'id': 'e7030bc5-fb6d-4e36-a992-72e53a2bd2cb',
#   'display': 'test/5.png',
#   'bbox': ['8186', '9404', '8950', '9528'],
#   'text': '+AUD45 A-A WH 0.75 FLRY PSPK 1000.0 3507992-Xx (F)',
#   'text_to_ignore': []},
#  {'id': 'e3a3fe87-4741-4eb1-b310-4481065fe9cf',
#   'display': 'test/5.png',
#   'bbox': ['9977', '8961', '11043', '9212'],
#   'text': 'PSPK Speaker Pedestrian Warning Ww X415',
#   'text_to_ignore': []},
#  {'id': '7ec7f482-0e73-472d-a380-9c3f6a4f80fe',
#   'display': 'test/5.png',
#   'bbox': ['10036', '9247', '10558', '9386'],
#   'text': 'X415-1 Analog In Speaker P',
#   'text_to_ignore': []},
#  {'id': '1433d1ee-f951-4e22-a389-3e0890aa9319',
#   'display': 'test/5.png',
#   'bbox': ['9227', '9348', '9794', '9424'],
#   'text': 'TWIST AUD44 A-A',
#   'text_to_ignore': []},
#  {'id': '477101e5-cfdd-445a-8c6f-159e43b9494b',
#   'display': 'test/5.png',
#   'bbox': ['10035', '9396', '10558', '9535'],
#   'text': 'X415-2 Analog In Speaker N',
#   'text_to_ignore': []},
#  {'id': '407fb19a-6537-4090-a33a-641871732df7',
#   'display': 'test/5.png',
#   'bbox': ['9728', '9472', '9918', '9528'],
#   'text': 'X415 ,',
#   'text_to_ignore': []},
#  {'id': 'f6efd887-d2a5-4913-a30c-9443b1a6a313',
#   'display': 'test/5.png',
#   'bbox': ['11657', '9066', '12045', '9138'],
#   'text': 'MATERIAL',
#   'text_to_ignore': []},
#  {'id': '54b89473-2133-4c5b-8948-226759327612',
#   'display': 'test/5.png',
#   'bbox': ['12598', '9064', '13020', '9138'],
#   'text': 'FINISHING',
#   'text_to_ignore': []},
#  {'id': '1745ae5a-67f6-4b32-a06c-d9f115bd735d',
#   'display': 'test/5.png',
#   'bbox': ['11732', '9141', '12476', '9239'],
#   'text': 'AS SPECIFIED',
#   'text_to_ignore': []},
#  {'id': '3a901a6d-3b8a-4041-a005-0734848ee5fa',
#   'display': 'test/5.png',
#   'bbox': ['12664', '9141', '13413', '9241'],
#   'text': 'AS SPECIFIED',
#   'text_to_ignore': []},
#  {'id': '563e6341-8d93-4cad-b8c8-c9ca842cd313',
#   'display': 'test/5.png',
#   'bbox': ['11652', '9292', '12925', '9467'],
#   'text': 'PART NAME Audio: MCU Amp & Radio',
#   'text_to_ignore': []},
#  {'id': 'b65086ce-4176-4259-8834-e564cbad3f55',
#   'display': 'test/5.png',
#   'bbox': ['11662', '9515', '12153', '9588'],
#   'text': 'PART NUMBER',
#   'text_to_ignore': []},
#  {'id': '1246cc5a-795e-46d8-9e9d-c37abac06845',
#   'display': 'test/5.png',
#   'bbox': ['13912', '8955', '14022', '8987'],
#   'text': '',
#   'text_to_ignore': []},
#  {'id': '5f6051b9-2734-4c89-86af-fed75b63ede9',
#   'display': 'test/5.png',
#   'bbox': ['13534', '9062', '13905', '9233'],
#   'text': 'SCALE NONE',
#   'text_to_ignore': []},
#  {'id': 'f0005a11-2071-456a-b5a4-07c4795852db',
#   'display': 'test/5.png',
#   'bbox': ['12785', '9513', '12996', '9587'],
#   'text': 'REV',
#   'text_to_ignore': []},
#  {'id': 'cc8b88e3-3b00-45b1-b001-19daf1aaff48',
#   'display': 'test/5.png',
#   'bbox': ['13083', '9514', '13366', '9587'],
#   'text': 'SHEET',
#   'text_to_ignore': []},
#  {'id': '02ae2246-8a9a-4ea5-b1a9-7e282e8a503c',
#   'display': 'test/5.png',
#   'bbox': ['13609', '9514', '13855', '9587'],
#   'text': 'SIZE',
#   'text_to_ignore': []},
#  {'id': '09bb62a7-8173-4367-9102-4a464dda72b7',
#   'display': 'test/5.png',
#   'bbox': ['13275', '9635', '13587', '9726'],
#   'text': 'oF 61',
#   'text_to_ignore': []},
#  {'id': '7f5652a1-eed6-4688-98d7-2f9d6512f02b',
#   'display': 'test/5.png',
#   'bbox': ['13648', '9635', '13857', '9728'],
#   'text': 'AO',
#   'text_to_ignore': []}]

# %% [markdown]
# # Preprocess Json

# %%
# from tqdm import tqdm
# from PIL import Image, ImageDraw,ImageFont
# # del temp_image
# # 1. "Cabin Climate"


# search_result = []
# images = []
# inputs = " "
# for i in tqdm(knowledge):
    
#     if inputs.lower() in i["text"].lower():
        
        
#         image_path =  "../" + i["display"].replace("//","/")
#         i["display"] = image_path
#         print(image_path)
#         images.append(image_path)
#         search_result.append(i)
        
# #         if image_path in imagedict:
# #             image = imagedict[image_path]
# #         else:
            
# #             image = Image.open(image_path)
        
# #         img1 = ImageDraw.Draw(image)
# #         bbox = [int(i) for i in i["bbox"]]
# #         img1.rectangle(bbox,outline ="red", width = 10)

# %%
search_result
# Out:
# []

# %%
# search_result = [{"bbox": [
#             "472",
#             "630",
#             "616",
#             "714"
#         ]}]

images = [f"/home/sohaib/Documents/rain/PDFParser/images/page_number_{page_number}/{page_number}.png"]
for i in images:
    image = Image.open(i)        
    img1 = ImageDraw.Draw(image)
    
    for results in knowledge:
        bbox = [int(i) for i in results["bbox"]]
        img1.rectangle(bbox,outline ="red", width = 10)
        if True:
            print(results["text"])
            myFont = ImageFont.truetype('/home/sohaib/Downloads/NewZurica_Bold.ttf', 30)

            img1.text((bbox[0], bbox[1]-30),results["text"],(0,0,0), font=myFont)
            
    name = i.split("/")[-1]
    image.save(f"./results/{name}")
# Out:
# Body Controller Right B,W,J,D XO50A B X051 X052 X054 X060A B X062 X053A B X055 X056 X058 X059
# X050B-10 High-Side Drive RADIO TUNER
#
# MCU & Gateway W,B,J,A X452 X453 X454 X800 X803 X801 X804 X802 X829 X860 X862 X455
# ——X050B
# X922M
# PAC11-B RD 0.35 FLRY ~CPGB 2594.0 3486395-XxX (B)
# —- X922F
# PAC11-A RD 0.35 FLRY ~CPGB 2321.0 3486406-XxX (T)
# ~CPGB Radio Tuner T,LT X439 X805F X807F
# X439-1 Power In ACC
# X439-4 Ground Ground
# 439
# GDLO1-H BK 0.35 FLRY ~CPGB 317.0 3486406-XxX (T)
# > GDLO1-A BK 1.00 FLRY 612.0 3486406-XX (T) Z52-GDLO1
# X454-11 Ethernet2Wire RADIO-BR-ETH P
# X454-12 Ethernet2Wire RADIO-BR-ETH N
# CAU50-A BU 0.35 FLRY TWIST-A2B CAUSO-A ~CPGB 2376.0 3486395- XB) WIST-A2B CAU50-A CAU51-A WH 0.35 FLRY. X922M x922M X454 ~CPGB 2376.0 3486395-XX (B)
# X453-9 Analog Out AMP1 2 P (DOOR FL)
# - X986M AUDO7 A-A WH 0.50 FLRY X986F AUDO7 A-A WH 0.50 FLRY . 871.0 3486395-Xx (B J i“ 14 1412.0 3486394-Xx (A) J — TWIST. -AUDO? A-A TWIST. AUDO7 A-A . TWIST aUD07 A -C TWIST AUDO7 A-C UD08 A-A BU 0.50 FLRY [ over 13113 —X986M UD08 AA BU 0.50 FLRY 871.0 3486395-XX (B) f f 1412.0 3486394-XXxX (A ) X032
# X453-10 Analog Out AMP1 2 N (DOOR FL)
# ) X922F CAU50-B BU 0.35. FLRY 2 ~CPGB 2321.0 3486406-XX (1) rN y900F TWIST-BRR CAU50-B TWIST-BRR CAU50-B X922F CAUS1-B WH 0.35 FLRY 3 ~ ~CPGB 2321.0 3486406-XX (1) Ih J X439
# X439-7 Digital In BR+
# X439-9 Digital In BR-
# Body Controller Left AW,J,D X030A B X031 X032 X034 X038A B X039 X037 X033A B X035 X036
# X032-4 Pass-through X033B-10 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH P AUDIO FRONT DOOR 2 PASSTHROUGH P
# X032-3 Pass-through X033B-19 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH N AUDIO FRONT DOOR 2 PASSTHROUGH N
# TWIST AUDO7 B-B
# X033B
# AUDO7 B-A WH 0.50 FLRY LHST 1383.13941 2486397-XX (D) TWIST AUDO7 B-B AUDO8 B-A YE 0.50 FLRY LHST 1383.13941 2486397-XX (D)
# X927M(
# X927F
# ) - X927F
# X927M
#
#
# vLOD
# AUDO7 B-A WH 0.75 FLRY LHST 865.0 1613836-XX (DT) TWIST AUDO7 B-D AUDO8 B-A YE 0.75 FLRY LHST 865.0 1613836-XX (DT)
# Speaker Door Front Fullrange DT X424
# X424-1 Power In Speaker P
# TWIST AUDO7 B-D
# X424-2 Power In Speaker N
# X424
# X453-8 Analog Out AMP2 2 P (DOOR FR)
# ~ TWIST AUDO9 A-A
# X453-7 Analog Out AMP2 2 N (DOOR FR)
# X453
# X454-10 Analog Out AMP3 1 P (IP LEFT)
# ~ TWIST AUD30 A-C
# X454-9 Analog Out AMP3 1 N (IP LEFT)
# AUDO9 A-A RD 0.50 FLRY 566 3486395-XX (B)
# AUD10 A-A GY 0.50 FLRY 566 3486395-XX (B)
# AUD30 A-A YE 0.50 FLRY 586 3486395-XX (B)
# AUD31 A-A VT 0.50 FLRY 586 3486395-XX (B)
# TWIST AUDO9 A-A
# X051)
# TWIST AUD30 A-C
# Body Controller Right B,W,J,D XO50A B X051 X052 X054 X060A B X062 X053A B X055 X056 X058 X059
# X051-9 Pass-through X053B-10 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH P AUDIO FRONT DOOR 2 PASSTHROUGH P
# X051-10 Pass-through X053B-19 Pass-through AUDIO FRONT DOOR 2 PASSTHROUGH N AUDIO FRONT DOOR 2 PASSTHROUGH N
# X051-13 Pass-through AUDIO LEFT IP PASSTHROUGH P
# X051-14 Pass-through AUDIO LEFT IP PASSTHROUGH N
# TWIST AUDO9 B-E
# X053B
# X055-1 Pass-through AUDIO LEFT IP PASSTHROUGH P
# ~ TWIST AUD30 B-F
# X055-2 Pass-through AUDIO LEFT IP LPASSTHROUGH N
# AUDO9 B-B WH 0.50 FLRY RHST 1601 2486398-XX (P)
# AUD10 B-B YE 0.50 FLRY RHST 1601 2486398-XX (P)
# AUD30 B-B GY 0.75 FLRY DRLH 629 3486401-XX (J)
# AUD31 B-B RD 0.75 FLRY DRLH 629 3486401-XX (J)
# - -X927F R
# X927M R
# TWIST AUDO9 B-E h x927M R
# X927F R Go
# aa X950F X950M 14 14 ; A - + yqgoq TWIST AUD30 B-E TWIST AUD30 B-F oso
# AUDO9 B-A WH 0.75 FLRY RHST 617.061553 1613836-XX (DT) TWIST AUDO9 B-D AUD10 B-A YE 0.75 FLRY RHST 617.061553 =1613836-XX (DT)
# AUD30 B-A GY 0.75 FLRY DRLH 1828 2494925-XX (JT)
# AUD31 B-A RD 0.75 FLRY DRLH 1828 2494925-XX (JT)
# Speaker Door Front Fullrange DT X424
# X424-1 Power In Speaker P
# TWIST AUDO9 B-D
# X424-2 Power In Speaker N
# X424
# Speaker IP Left ST X416
# X416-1 Power In Speaker P
# TWIST AUD30 B-E
# X416-2 Power In Speaker N
# X454
# X453-16 Analog Out AMP2 4 P (CENTER IP)
# ~ TWIST AUD32 A-C
# X453-15 Analog Out AMP2 4 N (CENTER IP)
# X453
# X454-7 Analog Out AMP3 3 P (IP RIGHT)
# ~ TWIST AUD34 A-C
# AUD32 A-A VT 0.50 FLRY 566 3486395-XX (B)
# AUD33 A-A GN 0.50 FLRY 566 3486395-XX (B)
# AUD34 A-A BU 0.50 FLRY 586 3486395-XX (B)
# X051)
# TWIST AUD32 A-C
# X051.
# TWIST AUD34 A-C
# X051-11 Pass-through AUDIO CENTER IP PASSTHROUGH P
# X055-31 Pass-through AUDIO CENTER IP PASSTHROUGH P
# X051-12 Pass-through AUDIO CENTER IP PASSTHROUGH N
# X055-32 Pass-through AUDIO CENTER IP PASSTHROUGH N
# X051-29 Pass-through AUDIO RIGHT IP PASSTHROUGH P
# X055
# TWIST AUD32 B-H
# iXO55
# X055-16 Pass-through AUDIO RIGHT IP PASSTHROUGH P
# TWIST AUD34 B-F
# AUD32 B-B GN 0.75 FLRY DRLH 629 3486401-XX (J)
# AUD33 B-B WH 0.75 FLRY DRLH 629 3486401-XX (J)
# AUD34 B-B YE 0.50 FLRY DRLH 629 3486401-XX (J)
#
# AUD32 B-A GN 0.75 FLRY X950F X950M i 1) 1 DRLH 1099.0 2494925-xx (JT) TWIST AUD32 B-H hy Al L . TWIST AUD32 B-G [ X8S0F X950M AUD33 B-A WH 0.75 FLRY DRLH 1099.0 2494925-xXx (JT) 15 15 A A
# . X950F X950M AUD34 B-A YE 0.50 FLRY TWIST AUD34.8-F etl TWISTAUDM4 BE - —" " X950F" X950M 7 ~~ AUD35 B-A BU 0.50 FLRY 17 17 DRLH 352.0 2494925-XX UT)
# X416
# Speaker IP Center JT X410
# X410-1 Power In Speaker P
# TWIST AUD32 B-G
# X410-2 Power In Speaker N
# X410
# Speaker IP Right ST X417
# X417-1 Power In Speaker P
# TWIST AUD34 B-E
#
# X453-11 Analog Out AMP1 1 P (APILLAR LEFT)
# X453-12 Analog Out AMP1 1 N (APILLAR LEFT)
# X454-8 Analog Out AMP3 3 N (IP RIGHT)
# X454
# ~ TWIST AUD36-D
# X453-6 Analog Out AMP2 1 P (APILLAR RIGHT)
# AUD35 A-A BN 0.50 FLRY 586 3486395-XX (B)
# AUD36-A GN 0.50 FLRY 871.0 3486395-XX (B)
# AUD37-A GY 0.50 FLRY 871.0 3486395-XX (B)
# AUD38-B RD 0.50 FLRY 838.0 3486395-XX (B)
# X051.
# X986F - X986M 11 1
# TWIST AUD36-D xoser © xesem TWIST AUD36-J oD 4 — 12 12
# X051-30 Pass-through AUDIO RIGHT IP PASSTHROUGH N
# AUD36-D GN 0.50 FLRY 1655.0 3486394-XX (A)
# AUD37-D GY 0.50 FLRY 1655.0 3486394-XX (A)
# X973M
# X973F
# X055-15 Pass-through AUDIO RIGHT IP PASSTHROUGH N
# 'X055
# X972M
# X972F
# - TWIST AUD36-J xe72M af - XO72F TWIST AUD36-E — 2 2 —
# AUD38-A RD 0.50 FLRY 422.0 1617078-XX (AT)
# AUD35 B-B BU 0.50 FLRY DRLH 629 3486401-XX (J)
# AUD36-B GN 0.50 FLRY 402.0 1617078-XX (AT)
# AUD37-B GY 0.50 FLRY 402.0 1617078-XX (AT)
# Speaker A-Pillar Lower Left Tweeter AT X450
# X450-1 Analog In Speaker P
# TWIST AUD36-E
# X450-2 Analog In Speaker N
# X450!
# Speaker A-Pillar Lower Right Tweeter AT X451
# X451-1 Analog In Speaker P
# X417-2 Power In Speaker N
# X417
# X453-5 Analog Out AMP2 1 N (APILLAR RIGHT)
# X454-4 Analog Out AMP3 2 P (HEADLINER FL)
# X454-3 Analog Out AMP3 2 N (HEADLINER FL)
#
# X453-1 Analog Out AMP1 4 P (HEADLINER FR)
# ~ TWIST AUD38-B
# X453
# TWIST AUD40-D
# X454
# TWIST AUD42-B
# AUD39-B WH 0.50 FLRY 838.0 3486395-XX (B)
# AUD40-A RD 0.50 FLRY 891.0 3486395-XX (B)
# AUD41-A BK 0.50 FLRY 891.0 3486395-XX (B)
# AUD42-B BU 0.50 FLRY 858 3486395-XX (B)
# ~ X986M
# X986F
# TWIST AUD40-D TWIST AUD40-J XO86F XO86M 10 10
# TWIST AUD38-B gran, yg7gp TWIST AUD38-C 2 2
# AUD40-D RD 0.50 FLRY 1655.0 3486394-XX (A)
# AUD41-D BK 0.50 FLRY 1655.0 3486394-XX (A)
#
# X973M(
# -Bo L TWIST AUD42-B xo7aM 7
# + KO73E TWIST AUD42-C
# AUD39-A WH 0.50 FLRY 422.0 1617078-XX (AT)
# X972M(
# X972F
# TWIST AUD40-J orang 7
# ' TWIST AUD40-E X972F ,
# AUD42-A BU 0.50 FLRY 531.0 1617078-XX (AT)
# AUD40-B RD 0.50 FLRY 511.0 1617078-XX (AT)
# AUD41-B) BK 0.50 FLRY 511.0 1617078-XX (AT)
# TWIST AUD38-C
# X451-2 Analog In Speaker N
# X451
# Speaker Headliner FL AT X443
# X443-1 Analog In Speaker P
# TWIST AUD40-E
# X443-2 Analog In Speaker N
# X443
# Speaker Headliner FR AT X444
# X444-1 Analog In Speaker P
# TWIST AUD42-C
#
# X453-2 Analog Out AMP1 4 N (HEADLINER FR)
# X453-3 Analog Out AMP1 3 P (HEADLINER RL)
# X453-4 Analog Out AMP 1 3 N (HEADLINER RL)
# X453-14 Analog Out AMP2 3 P (HEADLINER RR)
# X453-13 Analog Out AMP2 3 N (HEADLINER RR)
# TWIST AUD50-A
# TWIST AUD52-A
# X453
# AUD43-B GN 0.50 FLRY 858 3486395-XX (B)
# AUD50-A BU 0.75 FLRY 871.0 3486395-XX (B)
# AUD51-A BN 0.75 FLRY 871.0 3486395-XX (B)
# AUD52-A YE 0.75 FLRY 871.0 3486395-XX (B)
# AUD53-A BN 0.75 FLRY 871.0 3486395-XX (B)
# X986F
# - X986M
# TWIST AUDSO-A ogee
# 1 xo86M TWIST AUDS5O0-E 2
# X986F - X986M > H o
# TWIST AUDS2-A ogee
# xo86M h TWIST AUD52-E
# AUD50-B BU 0.75 FLRY 1642.0 3486394-XX (A)
# AUD51-B BN 0.75 FLRY 1642.0 3486394-XX (A)
# AUD52-B) YE 0.75 FLRY 1642.0 3486394-XX (A)
# AUD53-B BN 0.75 FLRY 1642.0 3486394-XX (A)
# AUD43-A GN 0.50 FLRY 531.0 1617078-XX (AT)
#
# TWIST AUD50-E “xoam Ty ~xgear TWIST AUDSO-D 26 26
# X968M
# X968F
# TWIST AUD52-E “xooen gat , TWIST AUDS2-D 15 15
# AUD50-A BU 0.75 FLRY 1663.0 3486403-XX (K)
# AUD51-A BN 0.75 FLRY 1663.0 3486403-XX (K)
# AUD52-A YE 0.75 FLRY 2817.0 3486403-XX (K)
# AUD53-A BN 0.75 FLRY 2817.0 3486403-XX (K)
# X444-2 Analog In Speaker N
# X444)
# Speaker Headliner RL K X441
# X441-1 Analog In Speaker P
# TWIST AUD50-D
# X441-2 Analog In Speaker N
# x441!
# Speaker Headliner RR K X442
# X442-1 Analog In Speaker P
# TWIST AUD52-D
# X442-2 Analog In Speaker N
# X442
#
#
# THE INFORMATION CONTAINED HEREIN IS DEEMED TO BE CONFIDENTIAL, PROPRIETARY, AND A TRADE SECRET OF TESLA MOTORS. THIS INFORMATION MAY NOT BE USED, REPRODUCED, OR DISCLOSED AS THE DIRECT OR INDIRECT BASIS FOR THE DEVELOPMENT, MANUFACTURE, OR SALE OF PROCESSES OR PRODUCTS WITHOUT THE EXPRESSD WRITTEN CONSENT OF TESLA MOTORS.
# CHECKED
# DRAWN
#
# APPROVED
#
# X454 upsized for SuperHorn TWIST AUD44 A-C +AUD44 A-C BU 0.75 FLRY PSPK 544 3486395-XX (B) +AUD45 A-C WH 0.75 FLRY PSPK 544 3486395-XX (B)
# X454-13 Analog Out AMP3 4 P (PSPK)
# X454-14 Analog Out AMP3 4 N (PSPK)
# X978F( X978M 10 10 TWIST AUD44 A-C x978F -X978M TWIST AUD44 A-B 20 20
# +AUD44 A-B BU 0.75 FLRY PSPK 2155 3486408-XX (W)
# +AUD45 A-B WH 0.75 FLRY PSPK 2155 3486408-XX (W)
#
# X964M (
# X964F
# TWIST AUD44 A-B “xoeam xO64F TWIST AUD44 A-A — 10110 —
# +AUD44 A-A BU 0.75 FLRY PSPK 1000.0 3507992-Xx (F)
# +AUD45 A-A WH 0.75 FLRY PSPK 1000.0 3507992-Xx (F)
# PSPK Speaker Pedestrian Warning Ww X415
# X415-1 Analog In Speaker P
# TWIST AUD44 A-A
# X415-2 Analog In Speaker N
# X415 ,
# MATERIAL
# FINISHING
# AS SPECIFIED
# AS SPECIFIED
# PART NAME Audio: MCU Amp & Radio
# PART NUMBER
#
# SCALE NONE
# REV
# SHEET
# SIZE
# oF 61
# AO

# %%
# Read Json File

import re
def filter_chars(text):
    ignored_chars = ["\\", "/",  "_", "|","{", "}","[","]","\"]
    for i in ignored_chars:
        text = text.replace(i, " ")
    text = re.sub(r'\s+', ' ', text)
    return text
    
    
new_dict = []

import json

json_file = "../images/page_number_3/results.json"

with open(json_file, 'r') as f:
    data = json.load(f)
    
for i in data:
#     print("Before ", i["text"] , "After ", filter_chars(i["text"]))
    
    i["text"] =filter_chars(i["text"])
    i["text"] = i["text"].strip()
    
    if i["text"] == " ": continue
    if len(i["text"]) == 0: continue
    new_dict.append(i)
        
    i["display"] =i["display"].replace("//","/")
    
    
#     i["text"] =i["text"].replace("\\","")
#     i["text"] =i["text"].replace("\\","")
#     i["text"] =i["text"].replace("{","")
#     i["text"] =i["text"].replace("}","")
#     i["text"] =i["text"].replace("[","")
#     i["text"] =i["text"].replace("]","")
    
    
import json
with open(json_file, 'w') as f:
    json.dump(new_dict, f)

# %%
"\\u2014 X011".replace("\\","")
# Out:
# 'u2014 X011'
